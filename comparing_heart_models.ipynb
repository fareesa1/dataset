# %% [markdown]
# <a href="https://colab.research.google.com/github/fareesa1/dataset/blob/master/comparing_heart_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DecisionTree
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
#DecisionTree
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import svm

#Load dataset
data = pd.read_csv("/content/sample_data/heart.csv")


#test train split
x = data.iloc[:,:-1]
y = data.iloc[:,13]
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)


# Normalize
X_train=(X_train-np.min(X_train))/(np.max(X_train)-np.min(X_train)).values
X_test=(X_test-np.min(X_test))/(np.max(X_test)-np.min(X_test)).values

# importing DecisionTreeClassifiertree
clf = tree.DecisionTreeClassifier()
#Training
clf = clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)

dataset1_dt = accuracy_score(y_test, y_pred)
print('DecisionTreeClassifier Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#Logistic Regression
# importing DecisionTreeClassifiertree
lg = LogisticRegression(random_state=0)
#Trainingk
lf = lg.fit(X_train, y_train)
y_pred=lg.predict(X_test)

dataset1_lg = accuracy_score(y_test, y_pred)
print('Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()


#NAIVE BAYES
gnb = GaussianNB()
#Training
lf = gnb.fit(X_train, y_train)
y_pred=gnb.predict(X_test)

dataset1_NB = accuracy_score(y_test, y_pred)
print('Naive Bayes Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#knn
# importing DecisionTreeClassifiertree
knn = KNeighborsClassifier(n_neighbors=3)
#Training
lf = knn.fit(X_train, y_train)
y_pred=knn.predict(X_test)

dataset1_knn = accuracy_score(y_test, y_pred)
print(' knn Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#svm
svm = svm.SVC()
#Training
svm= svm.fit(X_train, y_train)
y_pred=svm.predict(X_test)

dataset1_svm = accuracy_score(y_test, y_pred)
print('Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()
# Out:
# DecisionTreeClassifier Accuracy : 0.8032786885245902
# Confusion Matrix
# Accuracy : 0.8524590163934426
# Confusion Matrix
# Naive Bayes Accuracy : 0.8688524590163934
# Confusion Matrix
#  knn Accuracy : 0.8360655737704918
# Confusion Matrix
# Accuracy : 0.8524590163934426
# Confusion Matrix

# %%
print("--------Dataset-01 summary--------")
print("Logistic_regression:", dataset1_lg)
print("Desicion Tree:", dataset1_dt)
print("Naive Bayes:", dataset1_NB)
print("KnearestNeighbour:", dataset1_knn)
print("Support Vector Machines:", dataset1_svm)
# Out:
# --------Dataset-01 summary--------
# Logistic_regression: 0.8524590163934426
# Desicion Tree: 0.8032786885245902
# Naive Bayes: 0.8688524590163934
# KnearestNeighbour: 0.8360655737704918
# Support Vector Machines: 0.8524590163934426

# %%
#DecisionTree
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
#DecisionTree
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import svm

#Load dataset
data = pd.read_csv("/content/sample_data/heart2.csv")


#test train split
x = data.iloc[:,:-1]
y = data.iloc[:,13]
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)


# Normalize
X_train=(X_train-np.min(X_train))/(np.max(X_train)-np.min(X_train)).values
X_test=(X_test-np.min(X_test))/(np.max(X_test)-np.min(X_test)).values

# importing DecisionTreeClassifiertree
clf = tree.DecisionTreeClassifier()
#Training
clf = clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)

dataset2_dt = accuracy_score(y_test, y_pred)
print('DecisionTreeClassifier Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#Logistic Regression
# importing DecisionTreeClassifiertree
lg = LogisticRegression(random_state=0)
#Trainingk
lf = lg.fit(X_train, y_train)
y_pred=lg.predict(X_test)
dataset2_lg = accuracy_score(y_test, y_pred)
print('Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()


#NAIVE BAYES
gnb = GaussianNB()
#Training
lf = gnb.fit(X_train, y_train)
y_pred=gnb.predict(X_test)

dataset2_NB = accuracy_score(y_test, y_pred)
print('Naive Bayes Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#knn
# importing DecisionTreeClassifiertree
knn = KNeighborsClassifier(n_neighbors=3)
#Training
lf = knn.fit(X_train, y_train)
y_pred=knn.predict(X_test)

dataset2_knn = accuracy_score(y_test, y_pred)
print(' knn Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#svm
svm = svm.SVC()
#Training
svm= svm.fit(X_train, y_train)
y_pred=svm.predict(X_test)

dataset2_svm = accuracy_score(y_test, y_pred)
print('Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()
# Out:
# DecisionTreeClassifier Accuracy : 0.875
# Confusion Matrix
# Accuracy : 0.9017857142857143
# Confusion Matrix
# Naive Bayes Accuracy : 0.8482142857142857
# Confusion Matrix
#  knn Accuracy : 0.8392857142857143
# Confusion Matrix
# Accuracy : 0.9017857142857143
# Confusion Matrix

# %%
print("--------Dataset-01 summary--------")
print("Logistic_regression:", dataset2_lg)
print("Desicion Tree:", dataset2_dt)
print("Naive Bayes:", dataset2_NB)
print("KnearestNeighbour:", dataset2_knn)
print("Support Vector Machines:", dataset2_svm)
# Out:
# --------Dataset-01 summary--------
# Logistic_regression: 0.9017857142857143
# Desicion Tree: 0.875
# Naive Bayes: 0.8482142857142857
# KnearestNeighbour: 0.8392857142857143
# Support Vector Machines: 0.9017857142857143

# %%
#DecisionTree
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
#DecisionTree
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import svm

#Load dataset
data = pd.read_csv("/content/sample_data/heart3.csv")


#test train split
x = data.iloc[:,:-1]
y = data.iloc[:,13]
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)


# Normalize
X_train=(X_train-np.min(X_train))/(np.max(X_train)-np.min(X_train)).values
X_test=(X_test-np.min(X_test))/(np.max(X_test)-np.min(X_test)).values

# importing DecisionTreeClassifiertree
clf = tree.DecisionTreeClassifier()
#Training
clf = clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)

dataset3_dt = accuracy_score(y_test, y_pred)
print('DecisionTreeClassifier Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#Logistic Regression
# importing DecisionTreeClassifiertree
lg = LogisticRegression(random_state=0)
#Trainingk
lf = lg.fit(X_train, y_train)
y_pred=lg.predict(X_test)

dataset3_lg = accuracy_score(y_test, y_pred)
print('Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()


#NAIVE BAYES
gnb = GaussianNB()
#Training
lf = gnb.fit(X_train, y_train)
y_pred=gnb.predict(X_test)

dataset3_NB = accuracy_score(y_test, y_pred)
print('Naive Bayes Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#knn
# importing DecisionTreeClassifiertree
knn = KNeighborsClassifier(n_neighbors=3)
#Training
lf = knn.fit(X_train, y_train)
y_pred=knn.predict(X_test)

dataset3_knn = accuracy_score(y_test, y_pred)
print(' knn Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()

#svm
svm = svm.SVC()
#Training
svm= svm.fit(X_train, y_train)
y_pred=svm.predict(X_test)
dataset3_svm = accuracy_score(y_test, y_pred)
print('Accuracy :',accuracy_score(y_test, y_pred))
#print("DecisionTreeClassifier score  ",format(clf.score(X_train, y_train)))

cm=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
sns.heatmap(cm,annot=True)
plt.show()
# Out:
# DecisionTreeClassifier Accuracy : 0.9346733668341709
# Confusion Matrix
# Accuracy : 0.8442211055276382
# Confusion Matrix
# Naive Bayes Accuracy : 0.8140703517587939
# Confusion Matrix
#  knn Accuracy : 0.8693467336683417
# Confusion Matrix
# Accuracy : 0.8844221105527639
# Confusion Matrix

# %%
print("--------Dataset-03 summary--------")
print("Logistic_regression:", dataset3_lg)
print("Desicion Tree:", dataset3_dt)
print("Naive Bayes:", dataset3_NB)
print("KnearestNeighbour:", dataset3_knn)
print("Support Vector Machines:", dataset3_svm)
# Out:
# --------Dataset-03 summary--------
# Logistic_regression: 0.8442211055276382
# Desicion Tree: 0.9346733668341709
# Naive Bayes: 0.8140703517587939
# KnearestNeighbour: 0.8693467336683417
# Support Vector Machines: 0.8844221105527639

# %%
import matplotlib.pyplot as plt;

plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

#barchart
objects = ('NB','K-NN','SVM','DT','LR')
y_pos = np.arange(len(objects))
performance = [dataset3_NB,dataset3_knn,dataset3_svm,dataset3_dt,dataset3_lg]

plt.bar(y_pos, performance, align='center', alpha=0.6)
plt.xticks(y_pos, objects)
plt.ylabel('Accuracy')
plt.title('Comparing Different ML models for heart disease prediction')

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
# Data to pie Chart
labels = 'Naive Bayes','K-Nearest Neighbors','Kernelized SVM','Decision Tree','Logistic Regression'
sizes = [180,130,170,155,165]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','darkblue']
explode = (0.1, 0, 0, 0,0)  # explode 1st slice

# Plotcd

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

#nb:0.86-180
#knn:0.78-130
#svm:0.852-170
#dt:0.81-155
#lg:0.85-165
